# %% [markdown]
# # <center>Special lecture 1: min-cost flow problems</center>
# ### <center>Alfred Galichon (NYU & Sciences Po)</center>
# ## <center>'math+econ+code' masterclass on optimal transport and economic applications</center>
# #### <center>With python code examples</center>
# © 2018-2022 by Alfred Galichon. Past and present support from NSF grant DMS-1716489, ERC grant CoG-866274 are acknowledged, as well as inputs from contributors listed [here](http://www.math-econ-code.org/team).
#
# **If you reuse material from this masterclass, please cite as:**<br>
# Alfred Galichon, 'math+econ+code' masterclass on optimal transport and economic applications, January 2022. https://github.com/math-econ-code/mec_optim

# %% [markdown]
# ### Learning Objectives
#
# * Basic concepts of directed networks
#
# * The min-cost flow problem
#
# * Duality, optimality and equilibrium
#
# ### References
#
# * Galichon, *Optimal Transport Methods in Economics*. Ch.8.
#
# * Tolstoi (1930). Methods of finding the minimal total kilometrage in cargo transportation planning in space. *Transportation Planning* [in Russian]
#
# * Koopmans (1949). Optimum utilization of the transportation system. *Econometrica*.
#
# * Schrijver (2002). On the History of the Transportation and Maximum Flow Problems. *Mathematical programming*.

# %% [markdown]
# ## Motivation
#
# ### Motivation: network flow problems
#
# In 1930 Tolstoi, a Russian engineer, has to optimize the shipping of cement from factories to cities in the Soviet union through railway.
#
# * each factory produces a fixed number of tons
#
# * each city needs a fixed number of tons -- for now, we'll assume total production=total consumption
#
# * each factory is connected by rail with a few cities, and the corresponding distance is given
#
# * how to ship in order to minimize the total distance travelled?
#
# This problem belongs to the class of *min-cost flow problems*, an important class of linear programming problems, which are the focus of today's lecture. A decade before the invention of linear programming and the work of Kantorovich, Koopmans and Dantzig, Tolstoi described a heuristic method for solving the problem, which led to the optimal solution. As one can recover using modern tools, and will see that his solution was right.
#
# The *shortest path problem*, or how to find the path of minimal distance from a point to another in a network, also belongs in this class.

# %% [markdown]
# Fist, let's load libraries we'll need. We'll need `os` and `pandas` for data importation and manipulations, `numpy` and part of `scipy` for computations, `gurobipy` for linear programming using Gurobi, `osmnx` to import map data from [OpenStreetMap](https://www.openstreetmap.org/), `networkx` for operations on networks, parts of `matplotlib` for displays,

# %%
conda install -c "conda-forge/label/cf201901" osmnx
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working... failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\about\anaconda3
#
#   added / updated specs:
#     - osmnx
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-4.1.0               |             py_1         484 KB
#     branca-0.3.1               |             py_0          25 KB  conda-forge/label/cf201901
#     click-plugins-1.0.4        |             py_0           8 KB  conda-forge/label/cf201901
#     cligj-0.5.0                |             py_0           8 KB  conda-forge/label/cf201901
#     conda-23.1.0               |   py39haa95532_0         946 KB
#     descartes-1.1.0            |             py_2           6 KB  conda-forge/label/cf201901
#     expat-2.4.9                |       h6c2663c_0         207 KB
#     fiona-1.8.22               |   py39hac22706_0         681 KB
#     folium-0.7.0               |             py_0          54 KB  conda-forge/label/cf201901
#     freexl-1.0.6               |       h2bbff1b_0          51 KB
#     gdal-3.0.2                 |   py39hb978731_2         1.0 MB
#     geographiclib-1.49         |             py_0          32 KB  conda-forge/label/cf201901
#     geopandas-0.8.1            |     pyhd3eb1b0_0         895 KB
#     geopy-1.18.1               |             py_0          51 KB  conda-forge/label/cf201901
#     geos-3.8.0                 |       h33f27b4_0         905 KB
#     geotiff-1.7.0              |       h4545760_0         122 KB
#     hdf4-4.2.13                |    hf8e6fe8_1002         2.8 MB  conda-forge/label/cf201901
#     kealib-1.4.14              |       hde4a422_1         140 KB
#     libgdal-3.0.2              |       h3d7c30d_2         7.0 MB
#     libnetcdf-4.8.1            |       h6685c40_1         590 KB
#     libpq-12.9                 |       hb652d5d_3         2.7 MB
#     libspatialite-4.3.0a       |      h14feca5_20         2.3 MB
#     libzip-1.5.1               |    h2653d3f_1001         131 KB  conda-forge/label/cf201901
#     m2w64-expat-2.1.1          |                2         160 KB
#     m2w64-gcc-libgfortran-5.3.0|                6         340 KB
#     m2w64-gcc-libs-5.3.0       |                7         518 KB
#     m2w64-gcc-libs-core-5.3.0  |                7         213 KB
#     m2w64-gettext-0.19.7       |                2         4.2 MB
#     m2w64-gmp-6.1.0            |                2         689 KB
#     m2w64-libiconv-1.14        |                6         1.5 MB
#     m2w64-xz-5.2.2             |                2         395 KB
#     munch-2.3.2                |             py_0           8 KB  conda-forge/label/cf201901
#     osmnx-0.8.2                |             py_0          52 KB  conda-forge/label/cf201901
#     proj-6.2.1                 |       h3758d61_0         7.9 MB
#     pyproj-2.6.1.post1         |   py39h593ac45_1         320 KB
#     shapely-1.8.4              |   py39h9064783_0         364 KB
#     tiledb-2.3.3               |       h3649cd2_2         2.0 MB
#     vincent-0.4.4              |             py_1          28 KB  conda-forge/label/cf201901
#     xerces-c-3.2.4             |       hd77b12b_0         3.4 MB
#     ------------------------------------------------------------
#                                            Total:        42.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   altair             pkgs/main/noarch::altair-4.1.0-py_1
#   branca             conda-forge/label/cf201901/noarch::branca-0.3.1-py_0
#   click-plugins      conda-forge/label/cf201901/noarch::click-plugins-1.0.4-py_0
#   cligj              conda-forge/label/cf201901/noarch::cligj-0.5.0-py_0
#   descartes          conda-forge/label/cf201901/noarch::descartes-1.1.0-py_2
#   expat              pkgs/main/win-64::expat-2.4.9-h6c2663c_0
#   fiona              pkgs/main/win-64::fiona-1.8.22-py39hac22706_0
#   folium             conda-forge/label/cf201901/noarch::folium-0.7.0-py_0
#   freexl             pkgs/main/win-64::freexl-1.0.6-h2bbff1b_0
#   gdal               pkgs/main/win-64::gdal-3.0.2-py39hb978731_2
#   geographiclib      conda-forge/label/cf201901/noarch::geographiclib-1.49-py_0
#   geopandas          pkgs/main/noarch::geopandas-0.8.1-pyhd3eb1b0_0
#   geopy              conda-forge/label/cf201901/noarch::geopy-1.18.1-py_0
#   geos               pkgs/main/win-64::geos-3.8.0-h33f27b4_0
#   geotiff            pkgs/main/win-64::geotiff-1.7.0-h4545760_0
#   hdf4               conda-forge/label/cf201901/win-64::hdf4-4.2.13-hf8e6fe8_1002
#   kealib             pkgs/main/win-64::kealib-1.4.14-hde4a422_1
#   libgdal            pkgs/main/win-64::libgdal-3.0.2-h3d7c30d_2
#   libnetcdf          pkgs/main/win-64::libnetcdf-4.8.1-h6685c40_1
#   libpq              pkgs/main/win-64::libpq-12.9-hb652d5d_3
#   libspatialite      pkgs/main/win-64::libspatialite-4.3.0a-h14feca5_20
#   libzip             conda-forge/label/cf201901/win-64::libzip-1.5.1-h2653d3f_1001
#   m2w64-expat        pkgs/msys2/win-64::m2w64-expat-2.1.1-2
#   m2w64-gcc-libgfor~ pkgs/msys2/win-64::m2w64-gcc-libgfortran-5.3.0-6
#   m2w64-gcc-libs     pkgs/msys2/win-64::m2w64-gcc-libs-5.3.0-7
#   m2w64-gcc-libs-co~ pkgs/msys2/win-64::m2w64-gcc-libs-core-5.3.0-7
#   m2w64-gettext      pkgs/msys2/win-64::m2w64-gettext-0.19.7-2
#   m2w64-gmp          pkgs/msys2/win-64::m2w64-gmp-6.1.0-2
#   m2w64-libiconv     pkgs/msys2/win-64::m2w64-libiconv-1.14-6
#   m2w64-xz           pkgs/msys2/win-64::m2w64-xz-5.2.2-2
#   munch              conda-forge/label/cf201901/noarch::munch-2.3.2-py_0
#   osmnx              conda-forge/label/cf201901/noarch::osmnx-0.8.2-py_0
#   proj               pkgs/main/win-64::proj-6.2.1-h3758d61_0
#   pyproj             pkgs/main/win-64::pyproj-2.6.1.post1-py39h593ac45_1
#   shapely            pkgs/main/win-64::shapely-1.8.4-py39h9064783_0
#   tiledb             pkgs/main/win-64::tiledb-2.3.3-h3649cd2_2
#   vincent            conda-forge/label/cf201901/noarch::vincent-0.4.4-py_1
#   xerces-c           pkgs/main/win-64::xerces-c-3.2.4-hd77b12b_0
#
# The following packages will be UPDATED:
#
#   conda                              22.11.1-py39haa95532_4 --> 23.1.0-py39haa95532_0
#
#
#
# Downloading and Extracting Packages
#
# tiledb-2.3.3         | 2.0 MB    |            |   0%
#
# geopy-1.18.1         | 51 KB     |            |   0%
#
#
# munch-2.3.2          | 8 KB      |            |   0%
#
#
#
# geotiff-1.7.0        | 122 KB    |            |   0%
#
#
#
#
# libpq-12.9           | 2.7 MB    |            |   0%
#
#
#
#
#
# conda-23.1.0         | 946 KB    |            |   0%
#
#
#
#
#
#
# m2w64-libiconv-1.14  | 1.5 MB    |            |   0%
#
#
#
#
#
#
#
# cligj-0.5.0          | 8 KB      |            |   0%
#
#
#
#
#
#
#
#
# kealib-1.4.14        | 140 KB    |            |   0%
#
#
#
#
#
#
#
#
#
# freexl-1.0.6         | 51 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
# vincent-0.4.4        | 28 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# m2w64-gettext-0.19.7 | 4.2 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# m2w64-gcc-libgfortra | 340 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnetcdf-4.8.1      | 590 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geographiclib-1.49   | 32 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gdal-3.0.2           | 1.0 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# m2w64-gmp-6.1.0      | 689 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# expat-2.4.9          | 207 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libspatialite-4.3.0a | 2.3 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# tiledb-2.3.3         | 2.0 MB    |            |   1%
#
#
#
# geotiff-1.7.0        | 122 KB    | #3         |  13%
#
#
#
#
# libpq-12.9           | 2.7 MB    |            |   1%
# tiledb-2.3.3         | 2.0 MB    | 5          |   6%
#
#
#
# geotiff-1.7.0        | 122 KB    | #######8   |  79%
#
#
#
#
# libpq-12.9           | 2.7 MB    | 1          |   2%
# tiledb-2.3.3         | 2.0 MB    | #1         |  11%
#
#
#
#
# libpq-12.9           | 2.7 MB    | 5          |   5%
# tiledb-2.3.3         | 2.0 MB    | #5         |  15%
#
#
#
#
#
# conda-23.1.0         | 946 KB    | 1          |   2%
#
#
#
#
# libpq-12.9           | 2.7 MB    | 7          |   7%
#
#
#
# geotiff-1.7.0        | 122 KB    | ########## | 100%
# tiledb-2.3.3         | 2.0 MB    | ##         |  21%
#
#
#
#
#
# conda-23.1.0         | 946 KB    | #          |  10%
# tiledb-2.3.3         | 2.0 MB    | ##5        |  25%
#
#
#
#
# libpq-12.9           | 2.7 MB    | 9          |  10%
#
#
#
#
#
# conda-23.1.0         | 946 KB    | #5         |  15%
# tiledb-2.3.3         | 2.0 MB    | ###        |  30%
#
#
#
#
# libpq-12.9           | 2.7 MB    | #2         |  12%
#
#
#
#
#
# conda-23.1.0         | 946 KB    | ##1        |  22%
# tiledb-2.3.3         | 2.0 MB    | ###4       |  34%
#
#
#
#
# libpq-12.9           | 2.7 MB    | #3         |  14%
#
#
#
#
#
# conda-23.1.0         | 946 KB    | ##7        |  27%
# tiledb-2.3.3         | 2.0 MB    | ###7       |  38%
# tiledb-2.3.3         | 2.0 MB    | ####3      |  43%
#
#
#
#
#
# conda-23.1.0         | 946 KB    | ###3       |  34%
#
#
#
#
# libpq-12.9           | 2.7 MB    | #6         |  17%
# tiledb-2.3.3         | 2.0 MB    | #####      |  51%
#
#
#
#
#
# conda-23.1.0         | 946 KB    | ####2      |  42%
#
#
#
#
# libpq-12.9           | 2.7 MB    | #8         |  19%
#
#
#
#
#
# conda-23.1.0         | 946 KB    | ####7      |  47%
#
#
# munch-2.3.2          | 8 KB      | ########## | 100%
#
#
#
#
# libpq-12.9           | 2.7 MB    | ##         |  21%
#
#
# munch-2.3.2          | 8 KB      | ########## | 100%
#
#
#
#
#
# conda-23.1.0         | 946 KB    | ######     |  61%
# tiledb-2.3.3         | 2.0 MB    | #####6     |  57%
#
#
#
#
# libpq-12.9           | 2.7 MB    | ##4        |  25%
# tiledb-2.3.3         | 2.0 MB    | #######6   |  77%
#
#
#
#
#
# conda-23.1.0         | 946 KB    | #######2   |  73%
#
#
#
#
# libpq-12.9           | 2.7 MB    | ##7        |  27%
#
#
#
#
#
# conda-23.1.0         | 946 KB    | ########6  |  86%
#
#
#
#
# libpq-12.9           | 2.7 MB    | ###1       |  31%
# tiledb-2.3.3         | 2.0 MB    | ########3  |  84%
#
#
#
#
#
#
# m2w64-libiconv-1.14  | 1.5 MB    | 1          |   1%
#
#
#
#
# libpq-12.9           | 2.7 MB    | ###8       |  39%
#
# geopy-1.18.1         | 51 KB     | ###1       |  31%
#
#
#
#
#
#
#
#
# kealib-1.4.14        | 140 KB    | #1         |  11%
#
#
#
#
# libpq-12.9           | 2.7 MB    | ####2      |  42%
#
#
#
#
#
#
#
#
# kealib-1.4.14        | 140 KB    | ##2        |  23%
#
#
#
#
#
#
# m2w64-libiconv-1.14  | 1.5 MB    | 6          |   6%
#
#
#
#
#
# conda-23.1.0         | 946 KB    | ########## | 100%
#
#
#
#
#
# conda-23.1.0         | 946 KB    | ########## | 100%
#
#
#
#
# libpq-12.9           | 2.7 MB    | ######3    |  64%
#
#
#
#
#
#
# m2w64-libiconv-1.14  | 1.5 MB    | ###3       |  33%
#
#
#
#
#
#
# m2w64-libiconv-1.14  | 1.5 MB    | ####3      |  44%
#
#
#
#
#
#
#
#
#
# freexl-1.0.6         | 51 KB     | ###1       |  31%
#
#
#
#
# libpq-12.9           | 2.7 MB    | #######    |  71%
# tiledb-2.3.3         | 2.0 MB    | ########## | 100%
# tiledb-2.3.3         | 2.0 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# m2w64-gettext-0.19.7 | 4.2 MB    |            |   0%
#
#
#
#
#
#
# m2w64-libiconv-1.14  | 1.5 MB    | ######2    |  63%
#
# geopy-1.18.1         | 51 KB     | ########## | 100%
#
#
#
#
# libpq-12.9           | 2.7 MB    | #######7   |  77%
#
# geopy-1.18.1         | 51 KB     | ########## | 100%
#
#
#
#
#
#
# m2w64-libiconv-1.14  | 1.5 MB    | ########2  |  82%
#
#
#
#
#
#
#
#
#
#
#
# m2w64-gettext-0.19.7 | 4.2 MB    | 1          |   2%
#
#
#
#
# libpq-12.9           | 2.7 MB    | ########2  |  82%
#
#
#
#
#
#
#
#
# kealib-1.4.14        | 140 KB    | ########## | 100%
#
#
#
#
#
#
#
#
# kealib-1.4.14        | 140 KB    | ########## | 100%
#
#
#
#
#
#
# m2w64-libiconv-1.14  | 1.5 MB    | #########4 |  95%
#
#
#
#
#
#
#
#
#
#
#
# m2w64-gettext-0.19.7 | 4.2 MB    | 3          |   3%
#
#
#
#
#
#
#
#
#
# freexl-1.0.6         | 51 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
# freexl-1.0.6         | 51 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# m2w64-gettext-0.19.7 | 4.2 MB    | 4          |   4%
#
#
#
#
# libpq-12.9           | 2.7 MB    | ########7  |  87%
#
#
#
#
#
#
# m2w64-libiconv-1.14  | 1.5 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# m2w64-gettext-0.19.7 | 4.2 MB    | #7         |  18%
#
#
#
#
#
#
#
#
#
#
#
# m2w64-gettext-0.19.7 | 4.2 MB    | ##3        |  23%
#
#
#
#
#
#
#
#
#
#
#
#
# m2w64-gcc-libgfortra | 340 KB    | 4          |   5%
#
#
#
#
#
#
#
#
#
#
#
#
# m2w64-gcc-libgfortra | 340 KB    | ##8        |  28%
#
#
#
#
#
#
#
# cligj-0.5.0          | 8 KB      | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnetcdf-4.8.1      | 590 KB    | 2          |   3%
#
#
#
#
#
#
#
#
#
#
#
# m2w64-gettext-0.19.7 | 4.2 MB    | ##8        |  29%
#
#
#
#
#
#
#
#
#
#
#
# m2w64-gettext-0.19.7 | 4.2 MB    | ######1    |  62%
#
#
#
#
# libpq-12.9           | 2.7 MB    | ########## | 100%
#
#
#
#
# libpq-12.9           | 2.7 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# m2w64-gmp-6.1.0      | 689 KB    | 2          |   2%
#
#
#
#
#
#
#
# cligj-0.5.0          | 8 KB      | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# m2w64-gmp-6.1.0      | 689 KB    | 4          |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gdal-3.0.2           | 1.0 MB    | 1          |   2%
#
#
#
#
#
#
#
#
#
#
#
#
# m2w64-gcc-libgfortra | 340 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# m2w64-gcc-libgfortra | 340 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# m2w64-gmp-6.1.0      | 689 KB    | ##5        |  26%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gdal-3.0.2           | 1.0 MB    | #5         |  15%
#
#
#
#
#
#
#
#
#
#
#
# m2w64-gettext-0.19.7 | 4.2 MB    | #######4   |  74%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnetcdf-4.8.1      | 590 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnetcdf-4.8.1      | 590 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gdal-3.0.2           | 1.0 MB    | ##4        |  25%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# m2w64-gmp-6.1.0      | 689 KB    | ###4       |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gdal-3.0.2           | 1.0 MB    | ###6       |  37%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# m2w64-gmp-6.1.0      | 689 KB    | ####8      |  49%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gdal-3.0.2           | 1.0 MB    | ####6      |  46%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# m2w64-gmp-6.1.0      | 689 KB    | ######2    |  63%
#
#
#
#
#
#
#
#
#
#
#
# m2w64-gettext-0.19.7 | 4.2 MB    | ########4  |  84%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gdal-3.0.2           | 1.0 MB    | #####9     |  60%
#
#
#
#
#
#
#
#
#
#
#
# m2w64-gettext-0.19.7 | 4.2 MB    | #########2 |  92%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# m2w64-gmp-6.1.0      | 689 KB    | #######4   |  74%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gdal-3.0.2           | 1.0 MB    | #######    |  71%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# m2w64-gmp-6.1.0      | 689 KB    | ########3  |  84%
#
#
#
#
#
#
#
#
#
#
#
# m2w64-gettext-0.19.7 | 4.2 MB    | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gdal-3.0.2           | 1.0 MB    | #########3 |  94%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# m2w64-gmp-6.1.0      | 689 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# m2w64-gmp-6.1.0      | 689 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# vincent-0.4.4        | 28 KB     | #####7     |  58%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geographiclib-1.49   | 32 KB     | ####9      |  50%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# expat-2.4.9          | 207 KB    | 7          |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libspatialite-4.3.0a | 2.3 MB    |            |   1%
#
#
#
#
#
#
#
#
#
#
#
# m2w64-gettext-0.19.7 | 4.2 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libspatialite-4.3.0a | 2.3 MB    | #####3     |  54%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gdal-3.0.2           | 1.0 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geographiclib-1.49   | 32 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geographiclib-1.49   | 32 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# vincent-0.4.4        | 28 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# vincent-0.4.4        | 28 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# expat-2.4.9          | 207 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# expat-2.4.9          | 207 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libspatialite-4.3.0a | 2.3 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working... failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\about\anaconda3
#
#   added / updated specs:
#     - osmnx
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     affine-2.4.0               |     pyhd8ed1ab_0          18 KB  conda-forge
#     branca-0.6.0               |     pyhd8ed1ab_0          27 KB  conda-forge
#     click-plugins-1.1.1        |             py_0           9 KB  conda-forge
#     cligj-0.7.2                |     pyhd8ed1ab_1          10 KB  conda-forge
#     conda-22.11.1              |   py39hcbf5309_1         908 KB  conda-forge
#     expat-2.4.8                |       h39d44d4_0         378 KB  conda-forge
#     folium-0.14.0              |     pyhd8ed1ab_0          71 KB  conda-forge
#     freexl-1.0.6               |       ha8e266a_0          58 KB  conda-forge
#     gdal-3.0.2                 |   py39hb978731_1         1.0 MB
#     geopandas-0.12.2           |     pyhd8ed1ab_0           7 KB  conda-forge
#     geopandas-base-0.12.2      |     pyha770c72_0         958 KB  conda-forge
#     geos-3.8.0                 |       he025d50_1         1.0 MB  conda-forge
#     geotiff-1.6.0              |       h5770a2b_0         128 KB
#     hdf4-4.2.13                |    h0e5069d_1005         1.1 MB  conda-forge
#     kealib-1.4.14              |       h96bfa42_2         158 KB  conda-forge
#     krb5-1.17.2                |       hbae68bd_0         856 KB  conda-forge
#     libgdal-3.0.2              |       ha1b3edf_1         7.0 MB
#     libnetcdf-4.6.1            |       hf59b723_4         501 KB
#     libpq-12.3                 |       h4f54205_3         3.7 MB  conda-forge
#     libspatialite-4.3.0a       |    he9c6e69_1033         4.3 MB  conda-forge
#     m2w64-expat-2.1.1          |                2         161 KB  conda-forge
#     m2w64-gcc-libgfortran-5.3.0|                6         342 KB  conda-forge
#     m2w64-gcc-libs-5.3.0       |                7         520 KB  conda-forge
#     m2w64-gcc-libs-core-5.3.0  |                7         214 KB  conda-forge
#     m2w64-gettext-0.19.7       |                2         4.0 MB  conda-forge
#     m2w64-gmp-6.1.0            |                2         726 KB  conda-forge
#     m2w64-libiconv-1.14        |                6         1.5 MB  conda-forge
#     m2w64-xz-5.2.2             |                2         379 KB  conda-forge
#     mapclassify-2.5.0          |     pyhd8ed1ab_1          38 KB  conda-forge
#     munch-2.5.0                |             py_0          12 KB  conda-forge
#     osmnx-1.2.3                |     pyhd8ed1ab_0          75 KB  conda-forge
#     postgresql-12.3            |       h0f1a9bc_3        21.0 MB  conda-forge
#     proj-6.2.1                 |       ha7a8c7b_0         8.5 MB  conda-forge
#     python_abi-3.9             |           2_cp39           4 KB  conda-forge
#     rasterio-1.2.10            |   py39h17c1fa0_0         6.4 MB
#     snuggs-1.4.7               |             py_0           8 KB  conda-forge
#     tiledb-2.4.0               |       h78dabda_2         2.4 MB  conda-forge
#     xerces-c-3.2.3             |       h0e60522_5         3.8 MB  conda-forge
#     xyzservices-2022.9.0       |     pyhd8ed1ab_0          38 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        72.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   affine             conda-forge/noarch::affine-2.4.0-pyhd8ed1ab_0
#   branca             conda-forge/noarch::branca-0.6.0-pyhd8ed1ab_0
#   click-plugins      conda-forge/noarch::click-plugins-1.1.1-py_0
#   cligj              conda-forge/noarch::cligj-0.7.2-pyhd8ed1ab_1
#   expat              conda-forge/win-64::expat-2.4.8-h39d44d4_0
#   fiona              pkgs/main/win-64::fiona-1.8.22-py39hac22706_0
#   folium             conda-forge/noarch::folium-0.14.0-pyhd8ed1ab_0
#   freexl             conda-forge/win-64::freexl-1.0.6-ha8e266a_0
#   gdal               pkgs/main/win-64::gdal-3.0.2-py39hb978731_1
#   geopandas          conda-forge/noarch::geopandas-0.12.2-pyhd8ed1ab_0
#   geopandas-base     conda-forge/noarch::geopandas-base-0.12.2-pyha770c72_0
#   geos               conda-forge/win-64::geos-3.8.0-he025d50_1
#   geotiff            pkgs/main/win-64::geotiff-1.6.0-h5770a2b_0
#   hdf4               conda-forge/win-64::hdf4-4.2.13-h0e5069d_1005
#   kealib             conda-forge/win-64::kealib-1.4.14-h96bfa42_2
#   krb5               conda-forge/win-64::krb5-1.17.2-hbae68bd_0
#   libgdal            pkgs/main/win-64::libgdal-3.0.2-ha1b3edf_1
#   libnetcdf          pkgs/main/win-64::libnetcdf-4.6.1-hf59b723_4
#   libpq              conda-forge/win-64::libpq-12.3-h4f54205_3
#   libspatialite      conda-forge/win-64::libspatialite-4.3.0a-he9c6e69_1033
#   m2w64-expat        conda-forge/win-64::m2w64-expat-2.1.1-2
#   m2w64-gcc-libgfor~ conda-forge/win-64::m2w64-gcc-libgfortran-5.3.0-6
#   m2w64-gcc-libs     conda-forge/win-64::m2w64-gcc-libs-5.3.0-7
#   m2w64-gcc-libs-co~ conda-forge/win-64::m2w64-gcc-libs-core-5.3.0-7
#   m2w64-gettext      conda-forge/win-64::m2w64-gettext-0.19.7-2
#   m2w64-gmp          conda-forge/win-64::m2w64-gmp-6.1.0-2
#   m2w64-libiconv     conda-forge/win-64::m2w64-libiconv-1.14-6
#   m2w64-xz           conda-forge/win-64::m2w64-xz-5.2.2-2
#   mapclassify        conda-forge/noarch::mapclassify-2.5.0-pyhd8ed1ab_1
#   munch              conda-forge/noarch::munch-2.5.0-py_0
#   osmnx              conda-forge/noarch::osmnx-1.2.3-pyhd8ed1ab_0
#   postgresql         conda-forge/win-64::postgresql-12.3-h0f1a9bc_3
#   proj               conda-forge/win-64::proj-6.2.1-ha7a8c7b_0
#   pyproj             pkgs/main/win-64::pyproj-2.6.1.post1-py39h593ac45_1
#   python_abi         conda-forge/win-64::python_abi-3.9-2_cp39
#   rasterio           pkgs/main/win-64::rasterio-1.2.10-py39h17c1fa0_0
#   shapely            pkgs/main/win-64::shapely-1.8.4-py39h9064783_0
#   snuggs             conda-forge/noarch::snuggs-1.4.7-py_0
#   tiledb             conda-forge/win-64::tiledb-2.4.0-h78dabda_2
#   xerces-c           conda-forge/win-64::xerces-c-3.2.3-h0e60522_5
#   xyzservices        conda-forge/noarch::xyzservices-2022.9.0-pyhd8ed1ab_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   conda              pkgs/main::conda-22.11.1-py39haa95532~ --> conda-forge::conda-22.11.1-py39hcbf5309_1
#
#
#
# Downloading and Extracting Packages
#
# expat-2.4.8          | 378 KB    |            |   0%
#
# m2w64-gcc-libgfortra | 342 KB    |            |   0%
#
#
# libpq-12.3           | 3.7 MB    |            |   0%
#
#
#
# postgresql-12.3      | 21.0 MB   |            |   0%
#
#
#
#
# branca-0.6.0         | 27 KB     |            |   0%
#
#
#
#
#
# xerces-c-3.2.3       | 3.8 MB    |            |   0%
#
#
#
#
#
#
# mapclassify-2.5.0    | 38 KB     |            |   0%
#
#
#
#
#
#
#
# freexl-1.0.6         | 58 KB     |            |   0%
#
#
#
#
#
#
#
#
# geotiff-1.6.0        | 128 KB    |            |   0%
#
#
#
#
#
#
#
#
#
# libnetcdf-4.6.1      | 501 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
# m2w64-expat-2.1.1    | 161 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# rasterio-1.2.10      | 6.4 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# hdf4-4.2.13          | 1.1 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# affine-2.4.0         | 18 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# m2w64-gcc-libs-5.3.0 | 520 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# m2w64-gmp-6.1.0      | 726 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# munch-2.5.0          | 12 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# osmnx-1.2.3          | 75 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
# branca-0.6.0         | 27 KB     | #####8     |  59%
#
# m2w64-gcc-libgfortra | 342 KB    | 4          |   5%
# expat-2.4.8          | 378 KB    | 4          |   4%
#
#
#
# postgresql-12.3      | 21.0 MB   |            |   0%
#
#
#
#
# branca-0.6.0         | 27 KB     | ########## | 100%
#
#
# libpq-12.3           | 3.7 MB    |            |   0%
#
# m2w64-gcc-libgfortra | 342 KB    | ####6      |  47%
# expat-2.4.8          | 378 KB    | ###3       |  34%
#
#
# libpq-12.3           | 3.7 MB    | 1          |   2%
#
#
#
# postgresql-12.3      | 21.0 MB   |            |   1%
#
# m2w64-gcc-libgfortra | 342 KB    | #######    |  70%
#
#
#
# postgresql-12.3      | 21.0 MB   |            |   1%
# expat-2.4.8          | 378 KB    | #####      |  51%
#
#
# libpq-12.3           | 3.7 MB    | 3          |   3%
#
#
#
#
#
# xerces-c-3.2.3       | 3.8 MB    |            |   0%
#
# m2w64-gcc-libgfortra | 342 KB    | #########3 |  93%
# expat-2.4.8          | 378 KB    | ######7    |  68%
#
#
#
# postgresql-12.3      | 21.0 MB   | 1          |   1%
#
#
# libpq-12.3           | 3.7 MB    | 5          |   5%
#
#
#
#
#
# xerces-c-3.2.3       | 3.8 MB    | 1          |   2%
#
#
#
# postgresql-12.3      | 21.0 MB   | 1          |   1%
#
# m2w64-gcc-libgfortra | 342 KB    | ########## | 100%
# expat-2.4.8          | 378 KB    | ########4  |  85%
#
#
#
# postgresql-12.3      | 21.0 MB   | 1          |   2%
#
#
#
#
#
# xerces-c-3.2.3       | 3.8 MB    | 3          |   3%
#
#
# libpq-12.3           | 3.7 MB    | 6          |   7%
#
#
#
#
#
#
# mapclassify-2.5.0    | 38 KB     | ####2      |  42%
# expat-2.4.8          | 378 KB    | ########## | 100%
# expat-2.4.8          | 378 KB    | ########## | 100%
#
#
#
#
#
# xerces-c-3.2.3       | 3.8 MB    | #2         |  13%
#
#
# libpq-12.3           | 3.7 MB    | #1         |  11%
#
#
#
# postgresql-12.3      | 21.0 MB   | 2          |   3%
#
#
#
#
#
#
# mapclassify-2.5.0    | 38 KB     | ########## | 100%
#
#
#
#
#
#
# mapclassify-2.5.0    | 38 KB     | ########## | 100%
#
#
#
#
#
# xerces-c-3.2.3       | 3.8 MB    | #7         |  18%
#
#
#
# postgresql-12.3      | 21.0 MB   | 2          |   3%
#
#
# libpq-12.3           | 3.7 MB    | #3         |  13%
#
#
#
#
#
#
#
# freexl-1.0.6         | 58 KB     | ##7        |  27%
#
#
# libpq-12.3           | 3.7 MB    | #6         |  16%
#
#
#
# postgresql-12.3      | 21.0 MB   | 3          |   3%
#
#
#
#
#
# xerces-c-3.2.3       | 3.8 MB    | ##1        |  22%
#
#
#
#
#
#
#
# freexl-1.0.6         | 58 KB     | ########## | 100%
#
#
#
#
#
#
#
# freexl-1.0.6         | 58 KB     | ########## | 100%
#
#
#
#
#
# xerces-c-3.2.3       | 3.8 MB    | ##5        |  26%
#
#
#
# postgresql-12.3      | 21.0 MB   | 3          |   4%
#
#
# libpq-12.3           | 3.7 MB    | #8         |  18%
#
#
#
#
#
#
#
#
# geotiff-1.6.0        | 128 KB    | #2         |  13%
#
#
#
# postgresql-12.3      | 21.0 MB   | 4          |   4%
#
#
#
#
#
# xerces-c-3.2.3       | 3.8 MB    | ###        |  31%
#
#
# libpq-12.3           | 3.7 MB    | ##2        |  22%
#
#
#
#
#
# xerces-c-3.2.3       | 3.8 MB    | ###5       |  35%
#
#
#
# postgresql-12.3      | 21.0 MB   | 4          |   4%
#
#
# libpq-12.3           | 3.7 MB    | ##4        |  24%
#
#
#
#
#
#
#
#
#
# libnetcdf-4.6.1      | 501 KB    | 3          |   3%
#
#
#
#
#
# xerces-c-3.2.3       | 3.8 MB    | ###9       |  39%
#
#
#
# postgresql-12.3      | 21.0 MB   | 4          |   5%
#
#
# libpq-12.3           | 3.7 MB    | ##6        |  26%
#
#
#
#
#
# xerces-c-3.2.3       | 3.8 MB    | #####2     |  53%
#
#
# libpq-12.3           | 3.7 MB    | ###2       |  32%
#
#
#
# postgresql-12.3      | 21.0 MB   | 5          |   5%
#
#
#
#
#
#
#
#
#
# libnetcdf-4.6.1      | 501 KB    | 9          |  10%
#
#
#
# postgresql-12.3      | 21.0 MB   | 5          |   6%
#
#
# libpq-12.3           | 3.7 MB    | ###6       |  37%
#
#
#
#
#
#
#
#
#
# libnetcdf-4.6.1      | 501 KB    | #5         |  16%
#
#
#
#
#
# xerces-c-3.2.3       | 3.8 MB    | #####8     |  59%
#
#
# libpq-12.3           | 3.7 MB    | ###9       |  39%
#
#
#
# postgresql-12.3      | 21.0 MB   | 6          |   6%
#
#
#
#
#
# xerces-c-3.2.3       | 3.8 MB    | ######6    |  66%
#
#
#
#
#
#
#
#
#
# libnetcdf-4.6.1      | 501 KB    | ##8        |  29%
#
#
#
#
#
#
#
#
#
# libnetcdf-4.6.1      | 501 KB    | ###8       |  38%
#
#
# libpq-12.3           | 3.7 MB    | ####3      |  44%
#
#
#
# postgresql-12.3      | 21.0 MB   | 6          |   7%
#
#
#
#
#
# xerces-c-3.2.3       | 3.8 MB    | #######2   |  72%
#
#
# libpq-12.3           | 3.7 MB    | ####7      |  47%
#
#
#
#
#
# xerces-c-3.2.3       | 3.8 MB    | #######6   |  77%
#
#
#
# postgresql-12.3      | 21.0 MB   | 7          |   7%
#
#
# libpq-12.3           | 3.7 MB    | #####      |  51%
#
#
#
# postgresql-12.3      | 21.0 MB   | 8          |   8%
#
#
#
#
#
# xerces-c-3.2.3       | 3.8 MB    | ########6  |  87%
#
#
# libpq-12.3           | 3.7 MB    | #####3     |  53%
#
#
#
#
#
# xerces-c-3.2.3       | 3.8 MB    | #########4 |  94%
#
#
#
# postgresql-12.3      | 21.0 MB   | 8          |   9%
#
#
# libpq-12.3           | 3.7 MB    | #####5     |  56%
#
#
#
#
#
#
#
#
#
# libnetcdf-4.6.1      | 501 KB    | ####4      |  45%
#
#
#
#
#
#
#
#
#
# libnetcdf-4.6.1      | 501 KB    | #######3   |  74%
#
#
#
# postgresql-12.3      | 21.0 MB   | 9          |  10%
#
#
# libpq-12.3           | 3.7 MB    | #####8     |  58%
#
#
#
#
#
# xerces-c-3.2.3       | 3.8 MB    | ########## | 100%
#
#
#
#
#
#
#
#
# geotiff-1.6.0        | 128 KB    | ###7       |  38%
#
#
#
#
#
# xerces-c-3.2.3       | 3.8 MB    | ########## | 100%
#
#
# libpq-12.3           | 3.7 MB    | ########   |  81%
#
#
#
# postgresql-12.3      | 21.0 MB   | #2         |  13%
#
#
#
#
#
#
#
#
#
#
# m2w64-expat-2.1.1    | 161 KB    | 9          |  10%
#
#
#
#
#
#
#
#
#
# libnetcdf-4.6.1      | 501 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# libnetcdf-4.6.1      | 501 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# hdf4-4.2.13          | 1.1 MB    | 1          |   1%
#
#
#
#
#
#
#
#
# geotiff-1.6.0        | 128 KB    | ########## | 100%
#
#
#
#
#
#
#
#
# geotiff-1.6.0        | 128 KB    | ########## | 100%
#
#
#
# postgresql-12.3      | 21.0 MB   | #3         |  13%
#
#
#
#
#
#
#
#
#
#
#
# rasterio-1.2.10      | 6.4 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
# m2w64-expat-2.1.1    | 161 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# m2w64-expat-2.1.1    | 161 KB    | ########## | 100%
#
#
# libpq-12.3           | 3.7 MB    | ########8  |  88%
#
#
#
#
#
#
#
#
#
#
#
#
# hdf4-4.2.13          | 1.1 MB    | #          |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
# affine-2.4.0         | 18 KB     | ########7  |  87%
#
#
#
#
#
#
#
#
#
#
#
#
#
# affine-2.4.0         | 18 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# affine-2.4.0         | 18 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# m2w64-gcc-libs-5.3.0 | 520 KB    | 3          |   3%
#
#
#
#
#
#
#
#
#
#
#
# rasterio-1.2.10      | 6.4 MB    |            |   1%
#
#
#
#
#
#
#
#
#
#
#
#
# hdf4-4.2.13          | 1.1 MB    | #9         |  19%
#
#
#
# postgresql-12.3      | 21.0 MB   | #4         |  14%
#
#
# libpq-12.3           | 3.7 MB    | #########4 |  94%
#
#
#
#
#
#
#
#
#
#
#
# rasterio-1.2.10      | 6.4 MB    | 1          |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# m2w64-gcc-libs-5.3.0 | 520 KB    | ###        |  31%
#
#
#
# postgresql-12.3      | 21.0 MB   | #4         |  15%
#
#
#
#
#
#
#
#
#
#
#
#
# hdf4-4.2.13          | 1.1 MB    | ##3        |  24%
#
#
#
#
#
#
#
#
#
#
#
# rasterio-1.2.10      | 6.4 MB    | 2          |   3%
#
#
# libpq-12.3           | 3.7 MB    | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# m2w64-gcc-libs-5.3.0 | 520 KB    | #####5     |  55%
#
#
#
#
#
#
#
#
#
#
#
#
# hdf4-4.2.13          | 1.1 MB    | ####2      |  43%
#
#
#
#
#
#
#
#
#
#
#
# rasterio-1.2.10      | 6.4 MB    | 3          |   3%
#
#
#
# postgresql-12.3      | 21.0 MB   | #5         |  16%
#
#
#
#
#
#
#
#
#
#
#
#
# hdf4-4.2.13          | 1.1 MB    | #####1     |  51%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# m2w64-gcc-libs-5.3.0 | 520 KB    | #######    |  71%
#
#
# libpq-12.3           | 3.7 MB    | ########## | 100%
#
#
#
# postgresql-12.3      | 21.0 MB   | ##         |  21%
#
#
#
#
#
#
#
#
#
#
#
# rasterio-1.2.10      | 6.4 MB    | ##         |  21%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# munch-2.5.0          | 12 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# m2w64-gmp-6.1.0      | 726 KB    | 2          |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# m2w64-gcc-libs-5.3.0 | 520 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# m2w64-gcc-libs-5.3.0 | 520 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# rasterio-1.2.10      | 6.4 MB    | ##3        |  24%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# m2w64-gmp-6.1.0      | 726 KB    | ##4        |  24%
#
#
#
# postgresql-12.3      | 21.0 MB   | ##2        |  22%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# osmnx-1.2.3          | 75 KB     | ##1        |  21%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# hdf4-4.2.13          | 1.1 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# hdf4-4.2.13          | 1.1 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# munch-2.5.0          | 12 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# osmnx-1.2.3          | 75 KB     | ########## | 100%
#
#
#
# postgresql-12.3      | 21.0 MB   | ##4        |  24%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# m2w64-gmp-6.1.0      | 726 KB    | ######1    |  62%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# osmnx-1.2.3          | 75 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# rasterio-1.2.10      | 6.4 MB    | ##7        |  27%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | 2          |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# m2w64-gmp-6.1.0      | 726 KB    | ########5  |  86%
#
#
#
#
#
#
#
#
#
#
#
# rasterio-1.2.10      | 6.4 MB    | ###        |  30%
#
#
#
# postgresql-12.3      | 21.0 MB   | ##5        |  25%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
# rasterio-1.2.10      | 6.4 MB    | ###2       |  32%
#
#
#
# postgresql-12.3      | 21.0 MB   | ##6        |  26%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | 3          |   3%
#
#
#
# postgresql-12.3      | 21.0 MB   | ##7        |  27%
#
#
#
#
#
#
#
#
#
#
#
# rasterio-1.2.10      | 6.4 MB    | ###4       |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | 4          |   4%
#
#
#
# postgresql-12.3      | 21.0 MB   | ##8        |  28%
#
#
#
#
#
#
#
#
#
#
#
# rasterio-1.2.10      | 6.4 MB    | ###6       |  37%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | 4          |   5%
#
#
#
# postgresql-12.3      | 21.0 MB   | ##8        |  29%
#
#
#
#
#
#
#
#
#
#
#
# rasterio-1.2.10      | 6.4 MB    | ###8       |  39%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# m2w64-gmp-6.1.0      | 726 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | 5          |   5%
#
#
#
# postgresql-12.3      | 21.0 MB   | ##9        |  30%
#
#
#
#
#
#
#
#
#
#
#
# rasterio-1.2.10      | 6.4 MB    | ####       |  40%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | 5          |   6%
#
#
#
#
#
#
#
#
#
#
#
# rasterio-1.2.10      | 6.4 MB    | ####1      |  41%
#
#
#
# postgresql-12.3      | 21.0 MB   | ###        |  30%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | 7          |   7%
#
#
#
#
#
#
#
#
#
#
#
# rasterio-1.2.10      | 6.4 MB    | ####2      |  42%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | 7          |   8%
#
#
#
# postgresql-12.3      | 21.0 MB   | ###        |  31%
#
#
#
#
#
#
#
#
#
#
#
# rasterio-1.2.10      | 6.4 MB    | ####3      |  44%
#
#
#
# postgresql-12.3      | 21.0 MB   | ###1       |  32%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | 8          |   8%
#
#
#
# postgresql-12.3      | 21.0 MB   | ###1       |  32%
#
#
#
#
#
#
#
#
#
#
#
# rasterio-1.2.10      | 6.4 MB    | ####5      |  45%
#
#
#
# postgresql-12.3      | 21.0 MB   | ###3       |  33%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | 9          |   9%
#
#
#
#
#
#
#
#
#
#
#
# rasterio-1.2.10      | 6.4 MB    | ####7      |  47%
#
#
#
# postgresql-12.3      | 21.0 MB   | ###8       |  38%
#
#
#
#
#
#
#
#
#
#
#
# rasterio-1.2.10      | 6.4 MB    | ######4    |  65%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | #4         |  14%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | #5         |  16%
#
#
#
#
#
#
#
#
#
#
#
# rasterio-1.2.10      | 6.4 MB    | #######    |  71%
#
#
#
# postgresql-12.3      | 21.0 MB   | ####       |  40%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | #7         |  18%
#
#
#
#
#
#
#
#
#
#
#
# rasterio-1.2.10      | 6.4 MB    | #######4   |  75%
#
#
#
# postgresql-12.3      | 21.0 MB   | ####1      |  42%
#
#
#
#
#
#
#
#
#
#
#
# rasterio-1.2.10      | 6.4 MB    | #######8   |  78%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | #9         |  20%
#
#
#
# postgresql-12.3      | 21.0 MB   | ####2      |  43%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | ##         |  21%
#
#
#
#
#
#
#
#
#
#
#
# rasterio-1.2.10      | 6.4 MB    | ########1  |  82%
#
#
#
# postgresql-12.3      | 21.0 MB   | ####3      |  44%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | ##2        |  22%
#
#
#
# postgresql-12.3      | 21.0 MB   | ####4      |  45%
#
#
#
#
#
#
#
#
#
#
#
# rasterio-1.2.10      | 6.4 MB    | ########4  |  85%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | ##5        |  26%
#
#
#
# postgresql-12.3      | 21.0 MB   | ####6      |  47%
#
#
#
#
#
#
#
#
#
#
#
# rasterio-1.2.10      | 6.4 MB    | #########2 |  93%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | ##7        |  27%
#
#
#
# postgresql-12.3      | 21.0 MB   | ####8      |  48%
#
#
#
#
#
#
#
#
#
#
#
# rasterio-1.2.10      | 6.4 MB    | #########6 |  96%
#
#
#
# postgresql-12.3      | 21.0 MB   | ####9      |  50%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | ##9        |  29%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | ###1       |  31%
#
#
#
# postgresql-12.3      | 21.0 MB   | #####      |  50%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | ###3       |  33%
#
#
#
# postgresql-12.3      | 21.0 MB   | #####1     |  51%
#
#
#
#
#
#
#
#
#
#
#
# rasterio-1.2.10      | 6.4 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# rasterio-1.2.10      | 6.4 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | ###4       |  35%
#
#
#
# postgresql-12.3      | 21.0 MB   | #####1     |  52%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | ###5       |  36%
#
#
#
# postgresql-12.3      | 21.0 MB   | #####2     |  52%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | ###7       |  37%
#
#
#
# postgresql-12.3      | 21.0 MB   | #####2     |  53%
#
#
#
# postgresql-12.3      | 21.0 MB   | #####3     |  53%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | ###8       |  38%
#
#
#
# postgresql-12.3      | 21.0 MB   | #####3     |  54%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | ####       |  40%
#
#
#
# postgresql-12.3      | 21.0 MB   | #####4     |  54%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | ####1      |  41%
#
#
#
# postgresql-12.3      | 21.0 MB   | #####4     |  55%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | ####3      |  43%
#
#
#
# postgresql-12.3      | 21.0 MB   | #####5     |  56%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | ####4      |  44%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | ####5      |  45%
#
#
#
# postgresql-12.3      | 21.0 MB   | #####6     |  56%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | ####6      |  46%
#
#
#
# postgresql-12.3      | 21.0 MB   | #####7     |  57%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | ####7      |  47%
#
#
#
# postgresql-12.3      | 21.0 MB   | #####8     |  58%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | ####7      |  48%
#
#
#
# postgresql-12.3      | 21.0 MB   | #####8     |  59%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | ####9      |  50%
#
#
#
# postgresql-12.3      | 21.0 MB   | #####9     |  59%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | #####      |  50%
#
#
#
# postgresql-12.3      | 21.0 MB   | #####9     |  60%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | #####1     |  51%
#
#
#
# postgresql-12.3      | 21.0 MB   | ######     |  60%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | #####1     |  52%
#
#
#
# postgresql-12.3      | 21.0 MB   | ######     |  60%
#
#
#
# postgresql-12.3      | 21.0 MB   | ######3    |  64%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | #####9     |  59%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | ######1    |  61%
#
#
#
# postgresql-12.3      | 21.0 MB   | ######5    |  65%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | ######3    |  63%
#
#
#
# postgresql-12.3      | 21.0 MB   | ######6    |  66%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | ######4    |  64%
#
#
#
# postgresql-12.3      | 21.0 MB   | ######7    |  67%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | ######5    |  66%
#
#
#
# postgresql-12.3      | 21.0 MB   | ######7    |  68%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | ######6    |  67%
#
#
#
# postgresql-12.3      | 21.0 MB   | ######8    |  68%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | ######8    |  68%
#
#
#
# postgresql-12.3      | 21.0 MB   | ######8    |  69%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | ######9    |  70%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | #######    |  71%
#
#
#
# postgresql-12.3      | 21.0 MB   | ######9    |  69%
#
#
#
# postgresql-12.3      | 21.0 MB   | #######    |  70%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | #######1   |  72%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | #######2   |  73%
#
#
#
# postgresql-12.3      | 21.0 MB   | #######    |  71%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | #######3   |  73%
#
#
#
# postgresql-12.3      | 21.0 MB   | #######1   |  71%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | #######4   |  74%
#
#
#
# postgresql-12.3      | 21.0 MB   | #######1   |  72%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | #######5   |  75%
#
#
#
# postgresql-12.3      | 21.0 MB   | #######2   |  72%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | #######6   |  76%
#
#
#
# postgresql-12.3      | 21.0 MB   | #######2   |  73%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | #######6   |  77%
#
#
#
# postgresql-12.3      | 21.0 MB   | #######3   |  73%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | #######7   |  77%
#
#
#
# postgresql-12.3      | 21.0 MB   | #######3   |  73%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | #######8   |  78%
#
#
#
# postgresql-12.3      | 21.0 MB   | #######3   |  74%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | #######8   |  79%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | #######9   |  79%
#
#
#
# postgresql-12.3      | 21.0 MB   | #######4   |  74%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | ########   |  81%
#
#
#
# postgresql-12.3      | 21.0 MB   | #######4   |  75%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | ########1  |  81%
#
#
#
# postgresql-12.3      | 21.0 MB   | #######5   |  75%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | ########2  |  82%
#
#
#
# postgresql-12.3      | 21.0 MB   | #######5   |  76%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | ########2  |  83%
#
#
#
# postgresql-12.3      | 21.0 MB   | #######6   |  76%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | ########3  |  84%
#
#
#
# postgresql-12.3      | 21.0 MB   | #######7   |  77%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | ########5  |  85%
#
#
#
# postgresql-12.3      | 21.0 MB   | #######7   |  78%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | ########6  |  86%
#
#
#
# postgresql-12.3      | 21.0 MB   | #######7   |  78%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | ########7  |  87%
#
#
#
# postgresql-12.3      | 21.0 MB   | #######8   |  78%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | ########8  |  88%
#
#
#
# postgresql-12.3      | 21.0 MB   | #######8   |  79%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | ########9  |  89%
#
#
#
# postgresql-12.3      | 21.0 MB   | #######9   |  79%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | ########9  |  90%
#
#
#
# postgresql-12.3      | 21.0 MB   | #######9   |  79%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | #########  |  90%
#
#
#
# postgresql-12.3      | 21.0 MB   | #######9   |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | #########1 |  91%
#
#
#
# postgresql-12.3      | 21.0 MB   | ########   |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | #########1 |  92%
#
#
#
# postgresql-12.3      | 21.0 MB   | ########   |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | #########2 |  92%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | #########3 |  93%
#
#
#
# postgresql-12.3      | 21.0 MB   | ########   |  81%
#
#
#
# postgresql-12.3      | 21.0 MB   | ########1  |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | #########3 |  94%
#
#
#
# postgresql-12.3      | 21.0 MB   | ########1  |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | #########4 |  95%
#
#
#
# postgresql-12.3      | 21.0 MB   | ########2  |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | #########5 |  96%
#
#
#
# postgresql-12.3      | 21.0 MB   | ########2  |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | #########6 |  97%
#
#
#
# postgresql-12.3      | 21.0 MB   | ########2  |  83%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | #########7 |  98%
#
#
#
# postgresql-12.3      | 21.0 MB   | ########2  |  83%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | #########8 |  98%
#
#
#
# postgresql-12.3      | 21.0 MB   | ########3  |  83%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | #########9 |  99%
#
#
#
# postgresql-12.3      | 21.0 MB   | ########3  |  84%
#
#
#
# postgresql-12.3      | 21.0 MB   | ########3  |  84%
#
#
#
# postgresql-12.3      | 21.0 MB   | ########4  |  84%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgdal-3.0.2        | 7.0 MB    | ########## | 100%
#
#
#
# postgresql-12.3      | 21.0 MB   | ########7  |  87%
#
#
#
# postgresql-12.3      | 21.0 MB   | ########8  |  88%
#
#
#
# postgresql-12.3      | 21.0 MB   | ########9  |  89%
#
#
#
# postgresql-12.3      | 21.0 MB   | #########  |  90%
#
#
#
# postgresql-12.3      | 21.0 MB   | #########  |  91%
#
#
#
# postgresql-12.3      | 21.0 MB   | #########1 |  91%
#
#
#
# postgresql-12.3      | 21.0 MB   | #########1 |  92%
#
#
#
# postgresql-12.3      | 21.0 MB   | ########## | 100%
#
#
#
# postgresql-12.3      | 21.0 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.11.1
#   latest version: 23.1.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.1.0

# %%
conda install conda=23.1.0
# Out:
# Retrieving notices: ...working... done
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working... done
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\about\anaconda3
#
#   added / updated specs:
#     - conda=23.1.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     krb5-1.19.4                |       h5b6d351_0         786 KB
#     postgresql-12.9            |       hb652d5d_3        13.5 MB
#     ------------------------------------------------------------
#                                            Total:        14.3 MB
#
# The following packages will be UPDATED:
#
#   krb5                  conda-forge::krb5-1.17.2-hbae68bd_0 --> pkgs/main::krb5-1.19.4-h5b6d351_0
#   libgdal                                  3.0.2-ha1b3edf_1 --> 3.0.2-h3d7c30d_2
#   postgresql         conda-forge::postgresql-12.3-h0f1a9bc~ --> pkgs/main::postgresql-12.9-hb652d5d_3
#
#
#
# Downloading and Extracting Packages
#
# postgresql-12.9      | 13.5 MB   |            |   0%
#
# krb5-1.19.4          | 786 KB    |            |   0%
#
# krb5-1.19.4          | 786 KB    | 2          |   2%
#
# krb5-1.19.4          | 786 KB    | ##6        |  26%
# postgresql-12.9      | 13.5 MB   |            |   0%
#
# krb5-1.19.4          | 786 KB    | ####       |  41%
# postgresql-12.9      | 13.5 MB   |            |   1%
#
# krb5-1.19.4          | 786 KB    | ######3    |  63%
# postgresql-12.9      | 13.5 MB   |            |   1%
#
# krb5-1.19.4          | 786 KB    | ########1  |  81%
# postgresql-12.9      | 13.5 MB   | 1          |   2%
#
# krb5-1.19.4          | 786 KB    | #########7 |  98%
# postgresql-12.9      | 13.5 MB   | 2          |   2%
# postgresql-12.9      | 13.5 MB   | 3          |   4%
#
# krb5-1.19.4          | 786 KB    | ########## | 100%
# postgresql-12.9      | 13.5 MB   | 5          |   6%
# postgresql-12.9      | 13.5 MB   | 7          |   8%
# postgresql-12.9      | 13.5 MB   | 9          |   9%
# postgresql-12.9      | 13.5 MB   | #1         |  11%
# postgresql-12.9      | 13.5 MB   | #3         |  13%
# postgresql-12.9      | 13.5 MB   | #5         |  15%
# postgresql-12.9      | 13.5 MB   | #7         |  17%
# postgresql-12.9      | 13.5 MB   | #9         |  20%
# postgresql-12.9      | 13.5 MB   | ##2        |  23%
# postgresql-12.9      | 13.5 MB   | ##5        |  26%
# postgresql-12.9      | 13.5 MB   | ##8        |  29%
# postgresql-12.9      | 13.5 MB   | ###2       |  33%
# postgresql-12.9      | 13.5 MB   | ###6       |  36%
# postgresql-12.9      | 13.5 MB   | ####       |  40%
# postgresql-12.9      | 13.5 MB   | ####4      |  44%
# postgresql-12.9      | 13.5 MB   | ####8      |  48%
# postgresql-12.9      | 13.5 MB   | #####2     |  52%
# postgresql-12.9      | 13.5 MB   | #####6     |  57%
# postgresql-12.9      | 13.5 MB   | ######     |  61%
# postgresql-12.9      | 13.5 MB   | ######5    |  65%
# postgresql-12.9      | 13.5 MB   | ######9    |  70%
# postgresql-12.9      | 13.5 MB   | #######3   |  74%
# postgresql-12.9      | 13.5 MB   | #######7   |  78%
# postgresql-12.9      | 13.5 MB   | ########2  |  83%
# postgresql-12.9      | 13.5 MB   | ########6  |  87%
# postgresql-12.9      | 13.5 MB   | #########1 |  91%
# postgresql-12.9      | 13.5 MB   | #########5 |  96%
# postgresql-12.9      | 13.5 MB   | ########## | 100%
# postgresql-12.9      | 13.5 MB   | ########## | 100%
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/win-64::fiona==1.8.22=py39hac22706_0
#   - defaults/win-64::gdal==3.0.2=py39hb978731_2
#   - defaults/noarch::geopandas==0.8.1=pyhd3eb1b0_0
#   - defaults/win-64::libgdal==3.0.2=ha1b3edf_1
#   - conda-forge/noarch::osmnx==1.2.3=pyhd8ed1ab_0
#   - conda-forge/win-64::postgresql==12.3=h0f1a9bc_3
#   - defaults/win-64::rasterio==1.2.10=py39h17c1fa0_0
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.11.1
#   latest version: 23.1.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.1.0
#
#
#
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/win-64::fiona==1.8.22=py39hac22706_0
#   - defaults/win-64::gdal==3.0.2=py39hb978731_2
#   - defaults/noarch::geopandas==0.8.1=pyhd3eb1b0_0
#   - defaults/win-64::libgdal==3.0.2=ha1b3edf_1
#   - conda-forge/noarch::osmnx==1.2.3=pyhd8ed1ab_0
#   - conda-forge/win-64::postgresql==12.3=h0f1a9bc_3
#   - defaults/win-64::rasterio==1.2.10=py39h17c1fa0_0
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.11.1
#   latest version: 23.1.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.1.0

# %%
conda install -c networkx

# %%
import os
import pandas as pd
import numpy 
import scipy.sparse as sp
import osmnx as ox
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9364\953205639.py in <module>
#       3 import numpy
#       4 import scipy.sparse as sp
# ----> 5 import osmnx as ox
#
# ~\anaconda3\lib\site-packages\osmnx\__init__.py in <module>
#       1 """OSMnx init."""
#       2
# ----> 3 from ._api import *
#       4 from ._version import __version__
#
# ~\anaconda3\lib\site-packages\osmnx\_api.py in <module>
#       4 from .bearing import orientation_entropy
#       5 from .bearing import plot_orientation
# ----> 6 from .distance import k_shortest_paths
#       7 from .distance import nearest_edges
#       8 from .distance import nearest_nodes
#
# ~\anaconda3\lib\site-packages\osmnx\distance.py in <module>
#      23 # scikit-learn is optional dependency for unprojected nearest-neighbor search
#      24 try:
# ---> 25     from sklearn.neighbors import BallTree
#      26 except ImportError:  # pragma: no cover
#      27     BallTree = None
#
# ~\anaconda3\lib\site-packages\sklearn\__init__.py in <module>
#      80     from . import _distributor_init  # noqa: F401
#      81     from . import __check_build  # noqa: F401
# ---> 82     from .base import clone
#      83     from .utils._show_versions import show_versions
#      84
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in <module>
#      15 from . import __version__
#      16 from ._config import get_config
# ---> 17 from .utils import _IS_32BIT
#      18 from .utils._tags import (
#      19     _DEFAULT_TAGS,
#
# ~\anaconda3\lib\site-packages\sklearn\utils\__init__.py in <module>
#      26 from ..exceptions import DataConversionWarning
#      27 from .deprecation import deprecated
# ---> 28 from .fixes import np_version, parse_version
#      29 from ._estimator_html_repr import estimator_html_repr
#      30 from .validation import (
#
# ~\anaconda3\lib\site-packages\sklearn\utils\fixes.py in <module>
#      18 import scipy.sparse as sp
#      19 import scipy
# ---> 20 import scipy.stats
#      21 from scipy.sparse.linalg import lsqr as sparse_lsqr  # noqa
#      22 import threadpoolctl
#
# ~\anaconda3\lib\site-packages\scipy\stats\__init__.py in <module>
#     465 from ._warnings_errors import (ConstantInputWarning, NearConstantInputWarning,
#     466                                DegenerateDataWarning, FitError)
# --> 467 from ._stats_py import *
#     468 from ._variation import variation
#     469 from .distributions import *
#
# ~\anaconda3\lib\site-packages\scipy\stats\_stats_py.py in <module>
#      35 from numpy import array, asarray, ma
#      36 from numpy.lib import NumpyVersion
# ---> 37 from numpy.testing import suppress_warnings
#      38
#      39 from scipy.spatial.distance import cdist
#
# ~\anaconda3\lib\site-packages\numpy\testing\__init__.py in <module>
#       9
#      10 from . import _private
# ---> 11 from ._private.utils import *
#      12 from ._private.utils import (_assert_valid_refcount, _gen_alignment_data)
#      13 from ._private import extbuild, decorators as dec
#
# ~\anaconda3\lib\site-packages\numpy\testing\_private\utils.py in <module>
#     478
#     479
# --> 480 @np._no_nep50_warning()
#     481 def assert_almost_equal(actual,desired,decimal=7,err_msg='',verbose=True):
#     482     """
#
# ~\anaconda3\lib\site-packages\numpy\__init__.py in __getattr__(attr)
#     311             x = ones(2, dtype=float32)
#     312             if not abs(x.dot(x) - float32(2.0)) < 1e-5:
# --> 313                 raise AssertionError()
#     314         except AssertionError:
#     315             msg = ("The current Numpy installation ({!r}) fails to "
#
# AttributeError: module 'numpy' has no attribute '_no_nep50_warning'

# %%
import networkx as nx
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
# !python -m pip install -i https://pypi.gurobi.com gurobipy ## only if Gurobi not here
import gurobipy as grb
#thepath = os.path.join(os.getcwd(),'data_mec_optim/')
thepath = 'https://raw.githubusercontent.com/math-econ-code/mec_optim_2021-01/master/data_mec_optim/'

# %% [markdown]
# # A look at our data
#
# We will be looking at 3 types of data, which we each briefly describe.
#
#
#
# ## Soviet Planning Problem
#
# Tolstoi's original data, collected by Schrijver (2002). There are 68 Soviet cities and 10 factories, and 155 links connecting a factory to a city. This yields a sparse $68\times10$ matrix. Two vectors listing the demand of each city and the supply of each factory are also specified. This is stored in a $69\times11$ matrix, where we have appended the demand/supply vectors to the right and to the botton of the distance matrix.
#
# We read the data and display it.

# %%
soviet_df = pd.read_csv(thepath+'networks_sovietplanning/distances.csv', sep=',',encoding = "ISO-8859-1")

soviet_df

# %% [markdown]
# Plants and cities are the *nodes* of our network.
# There are *arcs* directly connecting when there is a railway from the plant to the city. In that case, the entry of the corresponding cell is equal to the length of the arc. When there is none, the corresponding cell shows `NaN`.
# We will index the nodes from to `nbPlants+nbCities`, with the plants being indexed by 0,1,...`nbPlants-1`, and the cities being indexed by `nbPlants`, `nbPlants+1`, ... , `nbPlants+nbCities`.
# Let us collect the arcs and their corresponding distances.

# %%
nbPlants = soviet_df.shape[1]-2
nbCities = soviet_df.shape[0]-1
arcsList = []
costslist = []
nodesList = [soviet_df.columns.values[plant+1]+' Plant' for plant in range(nbPlants)] + [soviet_df.iloc[city,0]+' city' for city in range(nbCities)]
for plant in range(nbPlants):
    for city in range(nbCities):
        if not pd.isna(soviet_df.iloc[city,plant+1]):
            #arcsList.append((plant,nbPlants+city))
            arcsList.append((nodesList[plant],nodesList[nbPlants+city]))
            costslist.append(soviet_df.iloc[city,plant+1])
nodesList = [soviet_df.columns.values[plant+1]+' Plant' for plant in range(nbPlants)] + [soviet_df.iloc[city,0]+' city' for city in range(nbCities)]

# %% [markdown]
# We will create a class `network_problem` to collect and story the relevant information we need: nodes, arcs, and arcs length. We will add methods later.

# %%
class network_problem:
    def __init__(self,nodesList,arcsList,costsList):
        self.nbNodes = len(nodesList)
        self.nbArcs = len(arcsList)
        self.nodesList = nodesList
        self.arcsList = arcsList
        self.costsList = costsList
        self.nodesDict = {node:node_ind for (node,node_ind) in zip(self.nodesList,range(self.nbNodes))}
        self.arcsDict = {arc:arc_ind for (arc,arc_ind) in zip(self.arcsList,range(self.nbArcs))}
        print('Number of nodes='+str(self.nbNodes)+'; number of arcs='+str(self.nbArcs)+'.')

soviet_pb = network_problem(nodesList,arcsList,costslist)

# %% [markdown]
# ## NYC subway network
#
# NYC subway network data: the network data are available on http://www.mta.info. This data is made of two files. The file `nodes.csv` lists the stations: each station is indexed by the line number; each line has the name of the station, and its spatial coordinates. The file `arcs.csv` lists the links between stations: each link specifies the index of the origin, the index of the destination, and the length of the segment.
#
# We shall store this information in a `network_problem` object called `subway_pb`.

# %%
arcs = pd.read_csv(thepath+'networks_subway/NYC/arcs.csv', sep=',')#.sort_values(by=['route_id'])
nodes = pd.read_csv(thepath+ 'networks_subway/NYC/nodes.csv', sep=',')
stopnames = [i+' '+j for i,j in zip(nodes.stop_name,nodes.route_id)]
arcsList = [(stopnames[o-1],stopnames[d-1]) for (o,d) in list(zip(arcs.from_stop_nb,arcs.to_stop_nb))]
subway_pb = network_problem(stopnames,arcsList,list(arcs.dis_line))

# %% [markdown]
# Stations' caracteristics are contained in `nodes` dataframe. The relevant information for us will be the name of the station, the horizontal spatial coordinate, and the vertical coordinates.

# %%
nodes.head(3)

# %% [markdown]
# Routes between stations are contained in `arcs` dataframe--the first column is the origin node, the second one is the destination node, and the third one is the length of the arc in meters.

# %%
arcs.head(3)

# %% [markdown]
# ## Paris streets
#
# Next, we gather data on the network of the Paris streets. To to this, we use the `osmnx` package to retrieve data from [OpenStreetMap](https://www.openstreetmap.org/). Doing this is as simple as specifying an address, and calling the `graph_from_address` function, specifying the desired distance (in meters) around this address.

# %%
nyu_address='57 boulevard Saint-Germain, 75005 Paris, France'
streets_network = ox.graph.graph_from_address(nyu_address, dist=2000,network_type = 'walk')
ox.plot_graph(streets_network,node_size=0, bgcolor='w')

# %% [markdown]
# As we see, the essential information we can extract from the graph is the list of nodes (`nodes_roads` below) and the list of arcs (`arcs_roads` below).

# %%
arcslist = [(i,j) for (i,j,k) in list(streets_network.edges)]
costslist = [streets_network[i][j][0]["length"] for i,j in arcslist ]
streets_pb = network_problem(list(streets_network.nodes),arcslist,costslist)

# %% [markdown]
# Now that we have the structure of the data in mind, let's develop the conceptual tools we shall need in our analysis.

# %% [markdown]
# ## Topology of networks
#
# ### Directed graph
#
# We start by defining the directed graph on which transportation takes place.
#
# ---
# **Definition**
#
# A (directed) *graph* $\left(\mathcal{Z},\mathcal{A}\right)$ is a set of *nodes* (cities) $\mathcal{Z}$, along with a set of *arcs* $\mathcal{A}\subseteq\mathcal{Z}^{2}$ which are pairs $\left(x,y\right)$ where $x\neq y\in\mathcal{Z}$.
#
# ---
# Our definition does not allow for an arc to have the same origin and destination. Note that for a dense network, $\left\vert \mathcal{A} \right\vert = \left\vert \mathcal{Z}\right\vert\left( \left\vert \mathcal{Z}\right\vert - 1 \right)$. For a line, $\left\vert \mathcal{A}\right\vert =\left\vert \mathcal{Z}\right\vert -1$.

# %% [markdown]
# **Stylized example**. Take the following example, which we shall use for exposition purposes:

# %%
example_graph = nx.DiGraph()
arcslist = [('s','u'),('u','v'),('s','v'),('u','t'),('v','t')]
costslist = [3,1,4,2,2]
example_graph.add_edges_from(arcslist)

example_pb = network_problem(list(example_graph.nodes),arcslist,costslist) 

pos = {'s':np.array([0,0]),'u':np.array([1,0.5]),'v':np.array([2,0]),'t':np.array([3,0])} 
nx.draw_networkx_edge_labels(example_graph,pos,edge_labels={e:('c='+str(l)) for (e,l) in zip(arcslist,costslist)},font_color='red')
nx.draw(example_graph,pos,with_labels=True)
plt.show()

# %% [markdown]
# ### Gradient matrix
#
# Next, we define the gradient matrix, which encodes the information contained in the directed graph.
#
# ---
# **Definition**
# <a name="grad_mat"></a>
#
# We define the *gradient matrix* (also called an `edge-node matrix') as the matrix with general term $\nabla_{ax}$, $a\in\mathcal{A}$, $x\in \mathcal{Z}$, such that
#
# \begin{align*}
# \nabla_{ax}  &  =-1\text{ if }a\text{ is out of }x\text{,}\\
# &  =+1\text{ if }a\text{ is into }x\text{,}\\
# &  =0\text{ else.}
# \end{align*}
#
# ---
#
# Hence, if $f\in\mathbb{R}^{\mathcal{Z}}$, then $\nabla f\in\mathbb{R}^{\mathcal{Z}}$, and $\left(  \nabla f\right)  _{xy}=f_{y}-f_{x}$.
#
# We shall denote $\nabla^{\intercal}$ the transpose of the gradient matrix. It is the network analog of the $-\operatorname{div}$ differential operator.

# %% [markdown]
# From the list of arcs, now we can easily construct our $\nabla$ matrix, as the first component of each element of `arcs` is the origin node (which will have $-1$ entry in $\nabla$) and the second component is the destination nodes (which will have $+1$ entry).
# An important feature of the matrix $\nabla$ is *sparsity*: for each row (arcs), there are only two nonzero terms. We should recognize this sparse structure and code $\nabla$ as a sparse matrix. In `scipy`, this is done using `csr_matrix`.
# We implement this as follows:

# %%
def Nabla(self):
    data = np.concatenate([-np.ones(self.nbArcs),np.ones(self.nbArcs)])
    arcsIndices = list(range(self.nbArcs))
    arcsOrigins = [self.nodesDict[o] for o,d in self.arcsList]
    arcsDestinations = [self.nodesDict[d] for o,d in self.arcsList]
    theNabla = sp.csr_matrix((data, (arcsIndices+arcsIndices, arcsOrigins+arcsDestinations)), shape = (self.nbArcs,self.nbNodes))
    return(theNabla)

network_problem.Nabla = Nabla

# %% [markdown]
# If we want to visualize, we need to convert it to a `np.array` matrix using the `.toarray()` method.
#
# **Stylized example**. In the case of our example, the matrix looks like the following:

# %%
example_pb.Nabla().toarray()

# %% [markdown]
# Take the first line in the example above, for instance, which is associated with the `uv` arc. It has a $-1$ entry on the first column entry (indicating leaving the node `u`), and a $+1$ entry on the second column entry (indicating entering the node `v`).

# %% [markdown]
# ### Paths and loops
#
# Next, we define the terms *paths* and *loops*.
#
# ---
# **Definition**
#
# Given two nodes $x$ and $y$, a *path* from $x$ to $y$ is a sequence $z_{1},z_{2},...,z_{K}$ in $\mathcal{Z}$ where $z_{1}=x$, $z_{K}=y$, and for every $1\leq k\leq K-1$, $\left(  z_{k},z_{k+1}\right)  \in\mathcal{A}$.
#
#
# A *loop* (also called `cycle') is a path from a node $x$ to itself.
#
# ---
#
# **Stylized example**. In our stylized example, `(s,u,v,t)` is a path, but `(s,v,u,t)` is not a path.

# %% [markdown]
# ### Transportation costs
#
# A vector $c\in\mathbb{R}^{\mathcal{A}}$ defines transportation costs. That is, for $xy\in\mathcal{A}$, $c_{xy}$ is the transportation cost associated to arc $xy$. $c$ can also be thought of as the length of arc $xy$. The cost of moving the good from node $x$ to node $y$ along path $z_{1},z_{2},...,z_{K}$ is
#
# \begin{align*}
# \sum_{k=1}^{K-1}c_{z_{k}z_{k+1}}.
# \end{align*}

# %% [markdown]
# ## Assumptions about the network
#
# We shall introduce a number of natural assumptions about the network.

# %% [markdown]
# ### No profitable loop
# ---
# **Assumption** [No profitable loop]
# <a name="noprofitloop"></a>
#
# There is no profitable loop, which means that there is no sequence $z_{1},...,z_{K}$ in $\mathcal{Z}$ such that $z_{K}=z_{1}$, $\left(  z_{k},z_{k+1}\right)  \in\mathcal{A}$, and $\sum_{k=1}^{K-1}c_{z_{k}z_{k+1}}<0$.
#
# ---
#
# In particular, there is no profitable loop if $c\geq0$.

# %% [markdown]
# ### Balancedness
# Let $q_{z}$ be the *net demand* at node $z \in \mathcal{Z}$, which is the quantity of goods disappearing from the graph. The set of nodes defined by
#
# \begin{align*}
# \mathcal{Z}_{0}=\left\{  x\in\mathcal{Z}:q_{x}<0\right\}  \text{, and }\mathcal{Z}_{1}=\left\{  y\in\mathcal{Z}:q_{y}>0\right\}
# \end{align*}
#
# are called the *supply nodes* and *demand nodes* respectively. A node which is neither a supply node, neither a demand node is called a *transit node*.
#
# Total supply is $-\sum_{x\in\mathcal{Z}_{0}}q_{x}$, total demand is $\sum_{y\in\mathcal{Z}_{1}}q_{y}$.
#
# ---
# **Assumption** [Balancedness]
# <a name="balancedness"></a>
#
# Assume that total supply equals total demand on the network, that is
#
# \begin{align*}
# \sum_{x\in\mathcal{Z}_{0}}q_{x}+\sum_{y\in\mathcal{Z}_{1}}q_{y}=0.
# \end{align*}
#
# ---

# %% [markdown]
# ### Connectedness
#
# ---
# **Assumption** [Connectedness]
# <a name="connectedness"></a>
#
# Assume the set of supply nodes $\mathcal{Z}_{0}$ is *strongly connected* to the set of demand nodes $\mathcal{Z}_{1}$, i.e. for every $x\in\mathcal{Z}_{0}$ and $y\in \mathcal{Z}_{1}$, there is a path from $x$ to $y$.
#
# ---

# %% [markdown]
# ### Regular networks
#
# The specification of the graph, the net demand vector, and the surplus vector
# defines a network.
#
# ---
# **Definition**
#
# A directed graph $\left(\mathcal{Z},\mathcal{A}\right)$ endowed with a net demand vector $\left(n_{z}\right)_{z \in \mathcal{Z}}$ and a cost vector $\left(c_{a}\right)_{a\in\mathcal{A}}$ is called a *network* $\left(\mathcal{Z}, \mathcal{A}, q, c\right)$. If the three assumptions above: [no profitable loop](#noprofitloop), [balancedness](#balancedness) and [connectedness](#connectedness) all hold, the network is called *regular*.
#
# ---
#
# Without mention of the contrary we shall assume that the network under consideration is regular.

# %% [markdown]
# ### Flows and feasible flows
#
# A *flow* is a vector $\mu$ on $\mathbb{R}_+^{\mathcal{A}}$, where $\mu_a$ is the quantity of mass passing through arc $a$.
#
# The flow of mass disappearing at $z$ equals the flow arriving from other nodes minus the flow shipping to other nodes
#
# \begin{align*}
# q_{z}=\sum_{x:xz \in\mathcal{A}}\mu_{xz}-\sum_{y:zy \in\mathcal{A}}\mu_{zy}
# \end{align*}
#
# and this equation can be rewritten as $\nabla^{\intercal}\mu=n$. This motivates the following definition:
#
# ---
# **Definition**
#
# The set of feasible flows associated with $q$, denoted $\mathcal{M}\left(  q\right)$, or $\mathcal{M}$ when there is no ambiguity, is defined as the set of flows $\mu\geq0$ that verify conservation equation
#
# \begin{align*}
#     \nabla^{\intercal}\mu=q.
# \end{align*}
#
# ---

# %% [markdown]
# **Stylized example**. In our stylized example, the flow of mass $\mu$ associated with arc `(s,u,v,t)` has one unit of mass on arcs `su`,`uv`, and `vt`. Hence,  $\nabla ^\top \mu$ is:

# %%
# example_pb.arcsList
# example_pb.nodesList
mu = np.array([1,1,0,0,1])
(example_pb.Nabla().transpose() * mu.reshape(-1,1)).reshape(1,-1)

# %% [markdown]
# We see that the vector of exiting flows $\nabla ^\top \mu$ is equal to $-1$ on arc `s`, equal to $1$ on arc `t`, and equal to zero elsewhere. Mass ''appears'' at the start of the path `s`, ''disappears'' at the end of the path `t`, and is conserved along the path and elsewhere in the network.
#
# Conversely, if $q_z = 1\{z=t\} - 1\{z=s\}$, and for $\mu\in\mathcal{M}(q)$, one may find a path from `s` to `t` along the support of $\mu$, by the following simple algorithm, which consists of looking for an arc in the support of $\mu$ originating at the current node, replacing the current node by the destination of the arc, and deleting the arc. It is easy to see that this algorithm will get from `s` to `t` in a finite number of steps. We implement it below:

# %%
def pathfinder(self,mu,sind,tind):
    # assume mu is such that $\Nabla^\top \mu =1 on t, =-1 on s, and =0 elsewhere
    t = self.nodesList[tind]
    arcs_active = [(x,y) for (x,y) in self.arcsList if (mu[self.arcsDict[(x,y)]] > 0) ]
    current = self.nodesList[sind]
    path = [current]
    while current != t:
        (x,y) = next((x,y) for (x,y) in arcs_active if x==current)
        path.append(y)
        current = y
        arcs_active.remove((x,y))
    return(path)
    

network_problem.pathfinder = pathfinder

# %% [markdown]
# **Stylized example**. We run this in our stylized example, to determine a path associated with `mu = np.array([1,1,0,0,1])` from `s`to `t`. We get:

# %%
example_pb.pathfinder(mu,0,3)

# %% [markdown]
# ## The min-cost flow problem
#
# Let $p_{z}$ be the price of the commodity at $z$. Consider the strategy which consists in purchasing the good at $x$, shipping to $y$, and selling at $y$. The profit of this strategy is
#
# \begin{align*}
# p_{y}-p_{x}-c_{xy}=\left(  \nabla p-c\right)_{xy}
# \end{align*}
#
# and hence there is no arbitrage opportunity if $p_{y}-p_{x}-c_{xy}\leq0$ for every arc $xy$, that is
#
# \begin{align*}
# \nabla p\leq c.
# \end{align*}
#
# Consider the *minimum cost flow problem*
# <a name="primal"></a>
# \begin{align*}
# &  \min_{\mu\geq0}\sum_{\left(  x,y\right)  \in\mathcal{A}}\mu_{xy}%
# c_{xy} \\
# &  s.t.~\nabla^{\intercal}\mu=q
# \end{align*}
#
# which is a linear programming problem whose dual is
# <a name="dual"></a>
# \begin{align*}
# &  \max_{p\in\mathbb{R}^{\mathcal{Z}}}\sum_{z\in\mathcal{Z}}p
# _{z} q_{z}\\
# &  s.t.~\nabla p\leq c.
# \end{align*}

# %% [markdown]
# ## Min-cost flow duality
#
# ---
# **Proposition**
# 1. Under Assumption [No profitable loop](#noprofitloop), the [dual problem](#dual) is feasible, which means that there is a vector $p\in\mathbb{R}^{\mathcal{Z}}$ such that $\nabla p\leq c$; and the value of [primal problem](#primal) is strictly less than $+\infty$.
#
# 2. Under Assumptions [balancedness](#balandedness) and [connectedness](#connectedness), the [primal problem](#primal) is feasible, which means that there is a flow $\mu\geq0$ such that $\nabla^{\intercal}\mu=q$; and the value of [dual problem](#dual) is strictly greater than $-\infty$.
#
# ---
#
# Assume that $\left(\mathcal{Z},\mathcal{A},q,c\right)$ is a regular network. Then the value of the [primal problem](#primal) coincides with the value of its [dual](#dual), and both problems have solutions. Further, if $\mu$ is a solution to the primal and $p$ is a solution to the dual, then $\mu_{xy}>0$ implies $p_{y}-p_{x}=c_{xy}$.

# %%
def network_problem_mincostflow(self,q,OutputFlag=True):
    Nabla = self.Nabla()
    m=grb.Model()
    m.setParam('OutputFlag', OutputFlag)
    p = m.addMVar(shape=self.nbNodes, name="p", lb = float('-inf'))
    m.setObjective(q @ p, grb.GRB.MAXIMIZE)
    m.addConstr( Nabla @ p <= np.array(self.costsList))
    m.optimize()
    if m.status == grb.GRB.Status.OPTIMAL:
        p_z = m.getAttr('x')
        mu_a = m.getAttr('pi')
    return np.array((p_z,mu_a),dtype=object)

network_problem.mincostflow =  network_problem_mincostflow

# %% [markdown]
# # Special cases
#
# ## Shortest path problem
#
# Assume there is only one source node $s \in \mathcal{Z}$ and one target node $t\in\mathcal{Z}$, each associated with unit flow. That is, $q_{z}=1\left\{  z=t\right\}  -1\left\{  z=s\right\}$. Then the problem boils down to how to push one unit of mass from $s$ to $t$. If we interpret $c_{xy}$ as the distance along arc $xy$, the solution of this problem corresponds to the shortest path from $s$ to $t$. This is why this problem is called shortest path problem. (More generally, this problem extends to the case when $c$ does not have a negative loop).
#
# The dual problem is then
#
# \begin{align*}
# \max_{p}  &  ~p_{t}-p_{s}\\
# s.t.  &  ~p_{y}-p_{x}\leq c_{xy}~\forall xy\in\mathcal{A}
# \end{align*}
#
# and we can impose normalization $p_{s}=0$, so that along the travelled path, $p_{z}$ interprets as the distance travelled thus far.

# %% [markdown]
# **Stylized example**. We run the min-cost flow problem in its ''shortest path'' version on our stylized example, with origin at node `s` and destination at node `t`.

# %%
p_z,mu_a = example_pb.mincostflow(np.array([[-1.,  0.,  0.,  1.]]))
print('\np_z='+str(p_z)+', and \nμ_a ='+str(mu_a) )
#example_pb.arcsList
example_pb.pathfinder(mu_a,0,3)

# %% [markdown]
# We see that the shortest path in the sytlized example is `sut`, with a total cost of 5.

# %% [markdown]
# **NYC subway dataset**. We now move on to the subway dataset, where we are trying to find the shortest path NYU to Columbia.

# %%
def network_problem_shortestPathLP(self,origin_node,destination_node, OutputFlag = True):
    q = np.zeros(self.nbNodes)
    q[origin_node] = -1
    q[destination_node] = 1
    p_z,mu_a = self.mincostflow(q,OutputFlag)
    return self.pathfinder(mu_a,origin_node,destination_node)

network_problem.shortestPathLP = network_problem_shortestPathLP

# %%
orig, dest = subway_pb.nodesDict['8 St - NYU (N/R)'] ,subway_pb.nodesDict['116 St - Columbia University (1)']
subway_pb.shortestPathLP(orig,dest )

# %% [markdown]
# **Paris streets dataset**. We shall now look for the shortest path between the centers of NYU and Columbia in Paris through the pedestrian network on the Parisian streets. First, let us use `osmnx`'s function `geocode` to convert the addresses into geographic coordinates, and then `get_nearest_node` to find the two nearest nodes on the network.

# %%
nyu_geocode  = ox.geocode('57 boulevard Saint-Germain, 75005 Paris, France') # NYU Paris
columbia_geocode = ox.geocode('4 Rue de Chevreuse, 75006 Paris') # Columbia in Paris
orig = streets_pb.nodesDict[ox.distance.nearest_nodes(streets_network, nyu_geocode[1],nyu_geocode[0])]
dest = streets_pb.nodesDict[ox.distance.nearest_nodes(streets_network, columbia_geocode[1],columbia_geocode[0])]

# %% [markdown]
# We determine the minumum cost flow using Gurobi, and obtain the shortest path accordingly:

# %%
path = streets_pb.shortestPathLP(orig,dest, OutputFlag = False)

# %% [markdown]
# We can plot the shortest path using `osmnx`'s `plot_graph_route` function.

# %%
fig, ax = ox.plot_graph_route(streets_network, path, route_linewidth=6, node_size=0, bgcolor='w')

# %% [markdown]
# We can describe the path using:

# %%
names = []
for i in range(len(path)-1):
    newitem = streets_network.edges[(path[i], path[i+1],0)]["name"]
    if type(newitem) == list:
        names = names+newitem.copy()
    else:
        names.append(newitem)
directions = []
oldname = ''
for name in names:
    if name != oldname:
        directions.append(name)
        oldname = name
print(directions)

# %% [markdown]
# ### Shortest path via dynamic programming
#
# We have advocated for the use of Gurobi as a black box in this problem, but there exists a direct method to find out the minimal cost path, using dynamic programming.
#
# The crucial remark here is that if there is a minimal cost path from $s$ to $t$, then there is one of length at most $\left\vert \mathcal{Z}\right\vert - 1$.
#
# For $z\in\mathcal{Z}$, and $t\in\mathbb{N}$, let $C_{sz}^{k}$ be the minimal cost of the path from $s$ to $z$ among paths of length at most $k$, with the convention that $C_{sz}^{k}=+\infty$ if there is no such path. One has:
#
# * $C_{ss}^{0}=0$ and $C_{sz}^{0}=+\infty$ for all $z\neq s$, and
#
# * for $t\geq1$, $C_{sz}^{k}$ satisfies the Bellman equation:
#
# \begin{align*}
# C_{sz}^{k}=\min\left\{  C_{sz}^{k},\min_{x\in\mathcal{Z}:sz\in\mathcal{A}%
# }\left\{  c_{sx}+C_{xz}^{k-1}\right\}  \right\}  .
# \end{align*}
#
# It is easy to see that $C_{st}^{\left\vert \mathcal{Z}\right\vert }$ is the minimal cost of any path from $s$ to $t$. Shortest-paths algorithms (Dijikstra and Bellman-Ford) implement this idea.
#
# In `networkx`, this is implemented using:

# %%
path_bis = nx.shortest_path(streets_network,streets_pb.nodesList[orig], streets_pb.nodesList[dest], weight='length')
path == path_bis

# %% [markdown]
# We can also translate the above idea into code and recover the shortest path from NYU to Columbia through the NYU subway network.

# %%
def network_problem_shortestPathDP(self,origin_node,destination_node, OutputFlag = True):
    successor = {z: None for z in self.nodesList}
    C_z = np.inf * np.ones(self.nbNodes)
    d_xy = np.array(self.costsList)
    C_z[destination_node] = 0
    delta_x_y = np.zeros((self.nbNodes,self.nbNodes))
    update = True
    while update:
        update = False
        for x,y in self.arcsList:
            xind,yind = self.nodesDict[x],self.nodesDict[y]
            if d_xy[self.arcsDict[(x,y)] ] +  C_z[yind]  < C_z[xind]:
                update = True
                C_z[xind] = d_xy[self.arcsDict[(x,y)] ] +  C_z[yind]
                successor[x]=y

    z = self.nodesList[origin_node]
    path = [z]
    while (successor[z] != self.nodesList[destination_node]):
        z = successor[z] 
        path.append(z)
    path.append(self.nodesList[destination_node])
    if OutputFlag == True:
        print("Cost = ",C_z[origin_node])
    return path

network_problem.shortestPathDP = network_problem_shortestPathDP

# %%
orig, dest = subway_pb.nodesDict['8 St - NYU (N/R)'] ,subway_pb.nodesDict['116 St - Columbia University (1)']
subway_pb.shortestPathDP(orig,dest )

# %% [markdown]
# ## Transportation problem
#
# Assume the problem is bipartite, that is $\mathcal{Z}=\mathcal{X}\cup\mathcal{Y}$ and $\mathcal{A}\subseteq\mathcal{X}\times\mathcal{Y}$. That is, there are no intermediate nodes, and an arc can only go directly from a source to a target.
#
# Note that any min-cost flow problem can be recast in this form, by taking the shortest distance between any source node and any target node.
#
# The dual problem is then
#
# \begin{align*}
# \max_{p}  &  ~\sum_{z\in\mathcal{Z}}p_{z}q_{z}\\
# s.t.  &  ~p_{y}-p_{x}\leq c_{xy}~\forall x\in\mathcal{X},y\in\mathcal{Y}
# \end{align*}
#
# which is our first encounter with optimal transport (more on this later in the course).

# %% [markdown]
# **Soviet planning dataset**. Back to the soviet planning dataset, we can now compute the optimal dispatch of each of the plant.

# %%
q = np.concatenate((-soviet_df.iloc[68,1:-1],soviet_df.iloc[0:-1,11]))
p_z,mu_a = soviet_pb.mincostflow(q)
